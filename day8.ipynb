# %%
# !python3 -m pip install matplotlib
# !python3 -m pip install opencv-python
# !python3 -m pip install scikit-image
# !python3 -m pip install pillow
# Out:
# ...
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.5 MB 1.3 MB/s eta 0:00:06
#      ---------------------------------------- 0.1/7.5 MB 907.3 kB/s eta 0:00:09
#       --------------------------------------- 0.1/7.5 MB 901.1 kB/s eta 0:00:09
#       --------------------------------------- 0.2/7.5 MB 1.1 MB/s eta 0:00:07
#      - -------------------------------------- 0.3/7.5 MB 1.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.4/7.5 MB 1.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.4/7.5 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.4/7.5 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.4/7.5 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.4/7.5 MB 1.3 MB/s eta 0:00:06
#      ---- ----------------------------------- 0.9/7.5 MB 1.8 MB/s eta 0:00:04
# ...

# %%
# pixel is ap function  of light at a certain point
# unsigned integer of 8 bit
# binarization use to take region of interst into computation

# %%
import cv2               # cv2 is for opencv2
import skimage
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
# open/show/save an image
img1 =  plt.imread('robot2.jpg')
plt.imshow(img1)

# %%
img1 =  plt.imread('robot2.jpg')
plt.imshow(img1)
plt.axis('off')
# Out:
# (-0.5, 1299.5, 1389.5, -0.5)

# %%
img1 =  plt.imread('robot2.jpg')
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
img2 = cv2.imread('robot.jpeg')
cv2.imshow('Image', img2)
cv2.waitKey(0)                # it must be 0 for static images   otherwise it will not get close

# %%
img2 = cv2.imread('robot.jpeg')
cv2.imshow('Image', img2)
cv2.waitKey(100)
cv2.destroyAllWindows()

# %%
img3 = skimage.io.imread('robot4.jpeg')
skimage.io.imshow(img3)

# %%
img3
# Out:
# array([[[147, 199, 239],
#         [147, 199, 239],
#         [148, 200, 240],
#         ...,
#         [247, 220, 193],
#         [248, 221, 194],
#         [250, 220, 196]],
#
#        [[147, 199, 239],
#         [147, 199, 239],
#         [148, 200, 240],
#         ...,
#         [245, 218, 189],
#         [248, 218, 190],
#         [248, 218, 192]],
#
#        [[146, 198, 238],
#         [147, 199, 239],
#         [148, 200, 240],
#         ...,
#         [244, 215, 185],
#         [245, 214, 185],
#         [245, 214, 185]],
#
#        ...,
#
#        [[ 35,  52,  72],
#         [ 31,  48,  68],
#         [ 25,  42,  62],
#         ...,
#         [ 76,  68,  49],
#         [ 76,  68,  49],
#         [ 85,  74,  56]],
#
#        [[ 35,  52,  72],
#         [ 31,  48,  68],
#         [ 25,  42,  62],
#         ...,
#         [ 75,  66,  49],
#         [ 75,  67,  48],
#         [ 85,  74,  56]],
#
#        [[ 35,  52,  72],
#         [ 31,  48,  68],
#         [ 25,  42,  62],
# ...

# %%
type(img3), type(img2), type(img1)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
img3.shape
# Out:
# (251, 201, 3)

# %%
import numpy as np
r1 = np.random.randint(0,255, (500,500,3))
plt.imshow(r1)

# %%
r2 = np.random.randint(0,255, (50,50))
plt.imshow(r2, cmap='gray')
#skimage.io.imshow(r2, cmap='gray')

# %%
r2 = np.random.randint(0,255, (50,50))
plt.imshow(r2)            # cmap is used to tell in gray color only
# Out:
# (-0.5, 49.5, 49.5, -0.5)

# %%
img = np.ones((50,50,3), dtype='uint8')*255
img[:25, 0:25, 1:] =  0
img[0:25, 25:, ::2] = 0
img[25:, 0:25, :2] = 0
img[25:, 25:, 2:] = 0
plt.imshow(img)

# %%
plt.imsave('squarebox.png', img)

# %%
skimage.io.imsave('squarebox2.png', img)

# %%
cv2.imwrite('squarebox3.png', img)
# Out:
# True

# %%
cv2.imshow('Image', img2)
cv2.waitKey(0)
# Out:
# -1

# %%
#plt.imshow(img2)        
plt.imshow(img2[:,:,::-1])       # RGB to BGR

# %%
# skimage.io.imshow(img2)
skimage.io.imshow(img2[:,:, ::-1])

# %%
# Note

#######################
# CV2 - True color image is BGR
# skimage - True color is RGB
# Matplotlib - True color is RGB
# PIL - True Color is RGB

# %%
cv2.imwrite('cv2 save.png', img2[:,:,::-1])
# Out:
# True
